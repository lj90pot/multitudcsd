# %%
from multitudcsd.config import get_spark_session, get_lakehouse_root, get_environment
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from multitudcsd.config import get_spark_session, get_lakehouse_root, get_environment
#       2
#
# ModuleNotFoundError: No module named 'multitudcsd.config'

# %%
print(get_environment())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(get_environment())
#
# NameError: name 'get_environment' is not defined
